# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiShved/python_lessons/blob/main/%D0%A2%D0%B8%D0%BF%D1%8B_%D0%B8_%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
null_variable = None
not_not_variable = 'something'
if null_variable == None:
    print("null_variable is None")
else:
    print("null_variable is not None")
if null_variable == None:
    print("not_null_variable is None")
else:
    print("not_null_variable is not None")
# Out:
# null_variable is None
# not_null_variable is None

# %%
a = 1
b = 0
print(a < b)
print(a > b)
print(a == b)
# Out:
# False
# True
# False

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(1)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type(5 + 4j)
# Out:
# complex

# %%
type([1, 5.3, False, 4])
# Out:
# list

# %%
type((1, True, 3, 5+4j))
# Out:
# tuple

# %%
type(range(5))
# Out:
# range

# %%
type("Hello")
# Out:
# str

# %%
type(b'a')
# Out:
# bytes

# %%
type(bytearray([1,2,3]))
# Out:
# bytearray

# %%
type(memoryview(bytearray('XYZ', 'utf-8')))
# Out:
# memoryview

# %%
type({'a', 3, True})
# Out:
# set

# %%
type(frozenset({1, 2, 3}))
# Out:
# frozenset

# %%
type({'a' : 32})
# Out:
# dict

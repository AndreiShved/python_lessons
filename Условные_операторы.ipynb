# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiShved/python_lessons/blob/main/%D0%A3%D1%81%D0%BB%D0%BE%D0%B2%D0%BD%D1%8B%D0%B5_%D0%BE%D0%BF%D0%B5%D1%80%D0%B0%D1%82%D0%BE%D1%80%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var = 5
if var < 10:
  print("var less than 10")
# Out:
# var less than 10

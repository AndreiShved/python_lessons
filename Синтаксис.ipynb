# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiShved/python_lessons/blob/main/%D0%A1%D0%B8%D0%BD%D1%82%D0%B0%D0%BA%D1%81%D0%B8%D1%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Python is awesome!")
# Out:
# Python is awesome!

# %%
var = "fist string"
print(var)
# Out:
# fist string

# %%
var = 2+9
print(var)
# Out:
# 11

# %%
print("Monty Python's flying circus")
# Out:
# Monty Python's flying circus

# %%
print('Monty Python's flying circus')
# Out:
#   File "<ipython-input-6-0cb0ba6b5a15>", line 1
#     print('Monty Python's flying circus')
#                         ^
# SyntaxError: invalid syntax

# %%
print("Monty Python\'s flying circus")
# Out:
# Monty Python's flying circus

# %%
print('String')
# Out:
# String

# %%
print("String")
# Out:
# String

# %%
print('''Str 
... ing''')
# Out:
# Str
# ing

# %%
print('Str"ing')
# Out:
# Str"ing

# %%
print("комментарий справа") #Функция print() позволяет выводить результат на экран комментарий справа
# Out:
# комментарий справа

# %%
var = 5
if var < 3:
  print("less")
else:
  print("more")
# Out:
# more

# %%
var = 6
if var > 4:
  if var > 5:
    print("more than 5")
# Out:
# more than 5

# %%
if var < 3: print("like this")

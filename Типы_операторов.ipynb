# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiShved/python_lessons/blob/main/%D0%A2%D0%B8%D0%BF%D1%8B_%D0%BE%D0%BF%D0%B5%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = True
b = False
print(a&b)
# Out:
# False

# %%
a = True
b = False
print(a&b|b)
# Out:
# False

# %%
a = True
b = False
print(a&b or not a&b)
# Out:
# True

# %%
a = True
b = False
print(a and b or not (a or b) or b)
# Out:
# False

# %%
a = True
b = False
print(b and b or not a and (a or b or a) or not (a or b))
# Out:
# False

# %%
a = True
b = False
print(1 << 2)
# Out:
# 4

# %%
a = True
b = False
print(1 & 0 | 1 >> 1)
# Out:
# 0

# %%
a = True
b = False
print(1 & 0 | 1 >> 0)
# Out:
# 1

# %%
a = True
b = False
print(0b101 & 0b111 ^ 0b111 | 0b010)
# Out:
# 2

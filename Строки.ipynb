# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiShved/python_lessons/blob/main/%D0%A1%D1%82%D1%80%D0%BE%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Abraсadabra"
print(s[2])
# Out:
# r

# %%
s = "Abraсadabra"
print(s[9])
# Out:
# r

# %%
s = "Abraсadabra"
print(s[0:5])
# Out:
# Abraс

# %%
len("Abraсadabra")
print(s[0:9])
# Out:
# Abraсadab

# %%
len("Abraсadabra")
# Out:
# 11
